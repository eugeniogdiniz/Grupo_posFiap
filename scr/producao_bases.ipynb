# %% [markdown]
# # Analise Exploratória dos dados
#
# O estudo de procução de vinhos vai começar pela sua produção, preparando a base para juntas às outras

# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

# %%
paises = ['Afeganistão', 'África do Sul', 'Alemanha, República Democrática',
   'Angola', 'Anguilla', 'Antígua e Barbuda', 'Antilhas Holandesas',
   'Argentina', 'Aruba', 'Austrália', 'Áustria', 'Bahamas',
   'Bangladesh', 'Barbados', 'Barein', 'Bélgica', 'Belice', 'Benin',
   'Bolívia', 'Bósnia-Herzegovina', 'Brasil', 'Bulgária',
   'Cabo Verde', 'Camarões', 'Canadá', 'Catar', 'Cayman, Ilhas',
   'Chile', 'China', 'Chipre', 'Cingapura', 'Cocos (Keeling), Ilhas',
   'Colômbia', 'Comores', 'Congo', 'Coreia, Republica Sul',
   'Costa do Marfim', 'Costa Rica', 'Croácia', 'Cuba', 'Curaçao',
   'Dinamarca', 'Dominica', 'El Salvador', 'Emirados Arabes Unidos',
   'Equador', 'Eslovaca, Republica', 'Espanha', 'Estados Unidos',
   'Estônia', 'Filipinas', 'Finlândia', 'França', 'Gana', 'Gibraltar',
   'Granada', 'Grécia', 'Guatemala', 'Guiana', 'Guiana Francesa',
   'Guine Bissau', 'Guine Equatorial', 'Haiti', 'Honduras',
   'Hong Kong', 'Hungria', 'Ilha de Man', 'Ilhas Virgens', 'India',
   'Indonésia', 'Irã', 'Iraque', 'Irlanda', 'Itália', 'Jamaica',
   'Japão', 'Jordânia', 'Letônia', 'Líbano', 'Libéria', 'Luxemburgo',
   'Malásia', 'Malta', 'Marshall, Ilhas', 'Mauritânia', 'México',
   'Moçambique', 'Montenegro', 'Namibia', 'Nicaragua', 'Nigéria',
   'Noruega', 'Nova Caledônia', 'Nova Zelândia', 'Omã',
   'Países Baixos', 'Panamá', 'Paraguai', 'Peru', 'Polônia',
   'Porto Rico', 'Portugal', 'Quênia', 'Reino Unido',
   'República Dominicana', 'Rússia', 'São Tomé e Príncipe',
   'São Vicente e Granadinas', 'Senegal', 'Serra Leoa', 'Singapura',
   'Suazilândia', 'Suécia', 'Suíça', 'Suriname', 'Tailândia',
   'Taiwan (FORMOSA)', 'Tanzânia', 'Tcheca, República', 'Togo',
   'Trinidade Tobago', 'Tunísia', 'Turquia', 'Tuvalu', 'Uruguai',
   'Vanuatu', 'Venezuela', 'Vietnã']

# Lista de continentes
continentes = [
    "Ásia", "África", "Europa", "África", "América do Norte", "América do Norte", "América do Norte",
    "América do Sul", "América do Norte", "Oceania", "Europa", "América do Norte",
    "Ásia", "América do Norte", "Ásia", "Europa", "América do Norte", "África",
    "América do Sul", "Europa", "América do Sul", "Europa", "América do Sul",
    "África", "África", "América do Norte", "Ásia", "América do Norte",
    "América do Sul", "Ásia", "Ásia", "Oceania",
    "América do Sul", "África", "África", "Ásia", "África",
    "América do Norte", "África", "América do Sul", "Europa", "América do Norte",
    "América do Norte", "Europa", "América do Norte", "Ásia",
    "Ásia", "Europa", "Oceania", "África", "Europa",
    "África", "América do Norte", "África", "Europa", "África",
    "América do Sul", "América do Sul", "África", "África",
    "América do Norte", "América do Norte", "Ásia", "Europa",
    "África", "Europa", "Oceania", "Ásia",
    "América do Norte", "América do Norte", "América do Norte", "Ásia", "África",
    "Europa", "Ásia", "África", "Europa", "Ásia",
    "Europa", "América do Norte", "Oceania", "América do Sul", "Europa",
    "América do Norte", "Europa", "África", "América do Norte",
    "África", "África", "África", "Ásia", "Ásia",
    "Ásia", "Europa", "África", "Europa", "Oceania",
    "África", "América do Norte", "África", "África", "Europa",
    "África", "Oceania", "Ásia", "América do Sul", "América do Sul",
    "América do Sul", "Europa", "América do Norte", "Europa",
    "América do Norte", "Europa", "África", "África", "Ásia",
    "África", "África", "África", "África", "América do Norte",
    "América do Sul", "Oceania", "América do Sul", "África", "América do Sul",
    "África", "Ásia"
]

# Criar um DataFrame Pandas
df_pais_continente = pd.DataFrame({'Pais': paises, 'Continentes': continentes})

# %%
df_pais_continente.head()
# Out:
#                               Pais       Continentes
# 0                      Afeganistão              Ásia
# 1                    África do Sul            África
# 2  Alemanha, República Democrática            Europa
# 3                           Angola            África
# 4                         Anguilla  América do Norte

# %%
producao_arquivo = r'/home/eugenio/Documentos/Pos/PosTechDataScience_Fiap/Grupo_posFiap/bases/vinho/Producao/Producao.csv'
df_producao_origin = pd.read_csv(producao_arquivo, sep=';')
df_producao_colunas = ['1970', '1971', '1972', '1973', '1974', '1975', '1976',
       '1977', '1978', '1979', '1980', '1981', '1982', '1983', '1984', '1985',
       '1986', '1987', '1988', '1989', '1990', '1991', '1992', '1993', '1994',
       '1995', '1996', '1997', '1998', '1999', '2000', '2001', '2002', '2003',
       '2004', '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012',
       '2013', '2014', '2015', '2016', '2017', '2018', '2019', '2020', '2021',
       '2022']
df_producao_anual = df_producao_origin.reset_index().melt(id_vars='produto', value_vars=df_producao_colunas)
df_producao_anual.columns = ['produto', 'ano', 'produzido']

# %%
lista_produtos = df_producao_anual['produto'].unique()
lista_produtos
# Out:
# array(['VINHO DE MESA', 'Tinto', 'Branco', 'Rosado',
#        'VINHO FINO DE MESA (VINÍFERA)', 'SUCO', 'Suco de uva integral',
#        'Suco de uva concentrado', 'Suco de uva adoçado',
#        'Suco de uva orgânico', 'Suco de uva reconstituído', 'DERIVADOS',
#        'Espumante', 'Espumante moscatel', 'Base espumante',
#        'Base espumante moscatel', 'Base Champenoise champanha',
#        'Base Charmat champanha', 'Bebida de uva', 'Polpa de uva',
#        'Mosto simples', 'Mosto concentrado', 'Mosto de uva com bagaço',
#        'Mosto dessulfitado', 'Mistelas', 'Néctar de uva', 'Licorosos',
#        'Compostos', 'Jeropiga', 'Filtrado', 'Frisante', 'Vinho leve',
#        'Vinho licoroso', 'Brandy', 'Destilado', 'Bagaceira',
#        'Licor de bagaceira', 'Vinagre', 'Borra líquida', 'Borra seca',
#        'Vinho Composto', 'Pisco', 'Vinho orgânico', 'Espumante orgânico',
#        'Destilado alcoólico simples de bagaceira ', 'Vinho acidificado ',
# ...

# %%
df_producao_anual_vinho_mesa = df_producao_anual.query("produto == 'VINHO DE MESA' | produto == 'VINHO FINO DE MESA (VINÍFERA)'")
df_producao_anual_vinho_mesa['tipo_vinho'] = 'VINHO DE MESA'
df_producao_anual_vinho_mesa.head(15)
# Out:
#                            produto   ano  produzido     tipo_vinho
# 0                    VINHO DE MESA  1970  217208604  VINHO DE MESA
# 4    VINHO FINO DE MESA (VINÍFERA)  1970   23899346  VINHO DE MESA
# 51                   VINHO DE MESA  1971  154264651  VINHO DE MESA
# 55   VINHO FINO DE MESA (VINÍFERA)  1971   23586062  VINHO DE MESA
# 102                  VINHO DE MESA  1972  146953297  VINHO DE MESA
# 106  VINHO FINO DE MESA (VINÍFERA)  1972   21078771  VINHO DE MESA
# 153                  VINHO DE MESA  1973  116710345  VINHO DE MESA
# 157  VINHO FINO DE MESA (VINÍFERA)  1973   12368410  VINHO DE MESA
# 204                  VINHO DE MESA  1974  193875345  VINHO DE MESA
# 208  VINHO FINO DE MESA (VINÍFERA)  1974   31644124  VINHO DE MESA
# 255                  VINHO DE MESA  1975  177401209  VINHO DE MESA
# 259  VINHO FINO DE MESA (VINÍFERA)  1975   39424590  VINHO DE MESA
# 306                  VINHO DE MESA  1976  144565438  VINHO DE MESA
# ...

# %%
df_producao_anual_vinho_mesa_agrupado = df_producao_anual_vinho_mesa.groupby(['tipo_vinho', 'ano']).agg({'produzido': 'sum'}).reset_index()
df_producao_anual_vinho_mesa_agrupado.head(15)
# Out:
#        tipo_vinho   ano  produzido
# 0   VINHO DE MESA  1970  241107950
# 1   VINHO DE MESA  1971  177850713
# 2   VINHO DE MESA  1972  168032068
# 3   VINHO DE MESA  1973  129078755
# 4   VINHO DE MESA  1974  225519469
# 5   VINHO DE MESA  1975  216825799
# 6   VINHO DE MESA  1976  179066028
# 7   VINHO DE MESA  1977  236624749
# 8   VINHO DE MESA  1978  236804602
# 9   VINHO DE MESA  1979  257382692
# 10  VINHO DE MESA  1980  162048848
# 11  VINHO DE MESA  1981  235477775
# 12  VINHO DE MESA  1982  292208145
# 13  VINHO DE MESA  1983  160878356
# 14  VINHO DE MESA  1984  225969610

# %%
df_exportacao_vinho = pd.read_csv(r'/home/eugenio/Documentos/Pos/PosTechDataScience_Fiap/Grupo_posFiap/bases/vinho/Exportacao/ExpVinho.csv', sep = ';')
df_exportacao_vinho = df_exportacao_vinho.drop("Id", axis=1) 
df_exportacao_vinho = df_exportacao_vinho.set_index("País") 
df_exportacao_vinho.head()
# Out:
#                                  1970  1970.1  1971  1971.1  1972  1972.1  \
# País
# Afeganistão                         0       0     0       0     0       0
# África do Sul                       0       0     0       0     0       0
# Alemanha, República Democrática     0       0     0       0  4168    2630
# Angola                              0       0     0       0     0       0
# Anguilla                            0       0     0       0     0       0
#
#                                   1973  1973.1  1974  1974.1  ...   2018  \
# País                                                          ...
# Afeganistão                          0       0     0       0  ...      0
# África do Sul                        0       0     0       0  ...      0
# Alemanha, República Democrática  12000    8250     0       0  ...  10794
# Angola                               0       0     0       0  ...    477
# Anguilla                             0       0     0       0  ...      0
#
# ...

# %%
Valores_dolar = ['1970.1', '1971.1', '1972.1', '1973.1', '1974.1', '1975.1',
       '1976.1', '1977.1', '1978.1', '1979.1', '1980.1', '1981.1',
       '1982.1', '1983.1', '1984.1', '1985.1', '1986.1', '1987.1', '1988.1',
       '1989.1', '1990.1', '1991.1', '1992.1', '1993.1', '1994.1',
       '1995.1', '1996.1', '1997.1', '1998.1', '1999.1', '2000.1', '2001.1', '2002.1', '2003.1', '2004.1', '2005.1', '2006.1', '2007.1',
       '2008.1', '2009.1', '2010', '2010.1', '2011.1', 
       '2012.1','2013.1', '2014.1',  '2015.1',
       '2016.1', '2017.1','2018.1', '2019.1',
       '2020.1', '2021.1', '2022.1']

# %%
Exportacao_litros = ['1970', '1971', '1972', '1973', '1974', '1975', '1976', '1977', '1978', 
                      '1979', '1980', '1981', '1982', '1983', '1984', '1985', '1986', '1987', 
                      '1988', '1989', '1990', '1991', '1992', '1993', '1994', '1995', '1996', '1997', 
                      '1998', '1999', '2000', '2001', '2002', '2003', '2004', '2005', '2006', '2007', 
                      '2008', '2009', '2010', '2010', '2011', '2012', '2013', '2014', '2015', '2016', 
                      '2017', '2018', '2019', '2020', '2021', '2022']

# %%
df_exportacao_vinho_dolar = df_exportacao_vinho.reset_index().melt(id_vars='País', value_vars=Valores_dolar)
df_exportacao_vinho_dolar.columns = ['Pais', 'Ano', 'U$$Valor_Exportacao']
df_exportacao_vinho_dolar['id_pais_ano'] = df_exportacao_vinho_dolar['Pais'] + df_exportacao_vinho_dolar['Ano']
df_exportacao_vinho_dolar['id_pais_ano'] = df_exportacao_vinho_dolar['id_pais_ano'].str.replace('.1', '')
df_exportacao_vinho_dolar['Ano'] = df_exportacao_vinho_dolar['Ano'].str.replace('.1', '')


df_exportacao_vinho_litros = df_exportacao_vinho.reset_index().melt(id_vars='País', value_vars=Exportacao_litros)
df_exportacao_vinho_litros.columns = ['Pais', 'Ano', 'Litros_Exportados']
df_exportacao_vinho_litros['id_pais_ano'] = df_exportacao_vinho_litros['Pais'] + df_exportacao_vinho_litros['Ano']

# %%
tabela_exportacao = pd.merge(df_exportacao_vinho_dolar, df_exportacao_vinho_litros, how='inner', on='id_pais_ano')
tabela_exportacao = tabela_exportacao[['Pais_x', 'Ano_x', 'U$$Valor_Exportacao', 'Litros_Exportados']]
tabela_exportacao.columns = ['Pais', 'Ano', 'U$$Valor_Exportacao', 'Litros_Exportados']
tabela_exportacao = pd.merge(tabela_exportacao, df_pais_continente, how='outer', on='Pais')
tabela_exportacao
# Out:
#              Pais   Ano  U$$Valor_Exportacao  Litros_Exportados Continentes
# 0     Afeganistão  1970                    0                  0        Ásia
# 1     Afeganistão  1971                    0                  0        Ásia
# 2     Afeganistão  1972                    0                  0        Ásia
# 3     Afeganistão  1973                    0                  0        Ásia
# 4     Afeganistão  1974                    0                  0        Ásia
# ...           ...   ...                  ...                ...         ...
# 6907       Vietnã  2018                    0                  0        Ásia
# 6908       Vietnã  2019                   32                 20        Ásia
# 6909       Vietnã  2020                  584                 86        Ásia
# 6910       Vietnã  2021                    0                  0        Ásia
# 6911       Vietnã  2022                  277                130        Ásia
#
# [6912 rows x 5 columns]

# %%
with pd.ExcelWriter(f'/home/eugenio/Documentos/Pos/PosTechDataScience_Fiap/Grupo_posFiap/bases/vinho/planilha_vinhos.xlsx') as writer:
            tabela_exportacao.to_excel(writer, sheet_name='tabela_exportacao', index=False)
            df_producao_anual_vinho_mesa_agrupado.to_excel(writer, sheet_name='df_producao_anual_vinho_mesa_agrupado', index=False)
            df_producao_anual_vinho_mesa.to_excel(writer, sheet_name='df_producao_anual_vinho_mesa', index=False)

# %%
tabela_exportacao['Pais'].unique()
# Out:
# array(['Afeganistão', 'África do Sul', 'Alemanha, República Democrática',
#        'Angola', 'Anguilla', 'Antígua e Barbuda', 'Antilhas Holandesas',
#        'Argentina', 'Aruba', 'Austrália', 'Áustria', 'Bahamas',
#        'Bangladesh', 'Barbados', 'Barein', 'Bélgica', 'Belice', 'Benin',
#        'Bolívia', 'Bósnia-Herzegovina', 'Brasil', 'Bulgária',
#        'Cabo Verde', 'Camarões', 'Canadá', 'Catar', 'Cayman, Ilhas',
#        'Chile', 'China', 'Chipre', 'Cingapura', 'Cocos (Keeling), Ilhas',
#        'Colômbia', 'Comores', 'Congo', 'Coreia, Republica Sul',
#        'Costa do Marfim', 'Costa Rica', 'Croácia', 'Cuba', 'Curaçao',
#        'Dinamarca', 'Dominica', 'El Salvador', 'Emirados Arabes Unidos',
#        'Equador', 'Eslovaca, Republica', 'Espanha', 'Estados Unidos',
#        'Estônia', 'Filipinas', 'Finlândia', 'França', 'Gana', 'Gibraltar',
#        'Granada', 'Grécia', 'Guatemala', 'Guiana', 'Guiana Francesa',
# ...

# %%
df_exportacao_vinho_dolar.head()
# Out:
#                               Pais   Ano  U$$Valor_Exportacao  \
# 0                      Afeganistão  1970                    0
# 1                    África do Sul  1970                    0
# 2  Alemanha, República Democrática  1970                    0
# 3                           Angola  1970                    0
# 4                         Anguilla  1970                    0
#
#                            id_pais_ano
# 0                      Afeganistão1970
# 1                    África do Sul1970
# 2  Alemanha, República Democrática1970
# 3                           Angola1970
# 4                         Anguilla1970

# %%
Valores_dolar = ['1970.1', '1971.1', '1972.1', '1973.1', '1974.1', '1975.1',
   '1976.1', '1977.1', '1978.1', '1979.1', '1980.1', '1981.1',
   '1982.1', '1983.1', '1984.1', '1985.1', '1986.1', '1987.1', '1988.1',
   '1989.1', '1990.1', '1991.1', '1992.1', '1993.1', '1994.1',
   '1995.1', '1996.1', '1997.1', '1998.1', '1999.1', '2000.1', '2001.1', '2002.1', '2003.1', '2004.1', '2005.1', '2006.1', '2007.1',
   '2008.1', '2009.1', '2010', '2010.1', '2011.1', 
   '2012.1','2013.1', '2014.1',  '2015.1',
   '2016.1', '2017.1','2018.1', '2019.1',
   '2020.1', '2021.1', '2022.1']

Valores_dolar_sem_ponto_um = [valor.replace(".1", "") for valor in Valores_dolar]

print(Valores_dolar_sem_ponto_um)
# Out:
# ['1970', '1971', '1972', '1973', '1974', '1975', '1976', '1977', '1978', '1979', '1980', '1981', '1982', '1983', '1984', '1985', '1986', '1987', '1988', '1989', '1990', '1991', '1992', '1993', '1994', '1995', '1996', '1997', '1998', '1999', '2000', '2001', '2002', '2003', '2004', '2005', '2006', '2007', '2008', '2009', '2010', '2010', '2011', '2012', '2013', '2014', '2015', '2016', '2017', '2018', '2019', '2020', '2021', '2022']

# %%
df_exportacao_vinhoT = df_exportacao_vinho.T

# %%
df_exportacao_vinhoT[df_exportacao_vinhoT.index.str.contains('.1')].index
# Out:
# Index(['1970.1', '1971', '1971.1', '1972.1', '1973.1', '1974.1', '1975.1',
#        '1976.1', '1977.1', '1978.1', '1979.1', '1980.1', '1981', '1981.1',
#        '1982.1', '1983.1', '1984.1', '1985.1', '1986.1', '1987.1', '1988.1',
#        '1989.1', '1990.1', '1991', '1991.1', '1992.1', '1993.1', '1994.1',
#        '1995.1', '1996.1', '1997.1', '1998.1', '1999.1', '2000.1', '2001',
#        '2001.1', '2002.1', '2003.1', '2004.1', '2005.1', '2006.1', '2007.1',
#        '2008.1', '2009.1', '2010', '2010.1', '2011', '2011.1', '2012',
#        '2012.1', '2013', '2013.1', '2014', '2014.1', '2015', '2015.1', '2016',
#        '2016.1', '2017', '2017.1', '2018', '2018.1', '2019', '2019.1',
#        '2020.1', '2021', '2021.1', '2022.1'],
#       dtype='object')

# %% [markdown]
# ## Separando os tipos de vinhos produzidos

# %% [markdown]
# Pensando nos tipos de Produtos que há para importação e exportação, avaliaremos os seguintes tipos:
#
# * Vinho de Mesa
# * Suco
# * Espumantes
# * Uvas/ Frescas

# %% [markdown]
# Vinho de Mesa

# %%
vinho_mesa = ['2-Tinto', '3-Branco', '4-Rosado']
producao_vinho_mesa = df_producao_anual.query("produto in @vinho_mesa")
plt.figure(figsize=(10,6))
plt.title('PRODUÇÃO DE VINHO DE MESA POR ANO')
axis = sns.lineplot(data= producao_vinho_mesa, x="ano", y="produzido", hue="produto")
axis.xaxis.set_major_locator(ticker.IndexLocator(base=5, offset=0))
plt.xticks(rotation=30)
plt.grid(linestyle='--')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /home/eugenio/Documentos/Pos/PosTechDataScience_Fiap/Grupo_posFiap/scr/producao_bases.ipynb Célula 23 line 7
#       <a href='vscode-notebook-cell:/home/eugenio/Documentos/Pos/PosTechDataScience_Fiap/Grupo_posFiap/scr/producao_bases.ipynb#X10sZmlsZQ%3D%3D?line=4'>5</a> axis = sns.lineplot(data= producao_vinho_mesa, x="ano", y="produzido", hue="produto")
#       <a href='vscode-notebook-cell:/home/eugenio/Documentos/Pos/PosTechDataScience_Fiap/Grupo_posFiap/scr/producao_bases.ipynb#X10sZmlsZQ%3D%3D?line=5'>6</a> axis.xaxis.set_major_locator(ticker.IndexLocator(base=5, offset=0))
# ----> <a href='vscode-notebook-cell:/home/eugenio/Documentos/Pos/PosTechDataScience_Fiap/Grupo_posFiap/scr/producao_bases.ipynb#X10sZmlsZQ%3D%3D?line=6'>7</a> plt.xticks(rotation=30)
# ...

# %% [markdown]
# Vinho de Mesa Vinífera

# %%
vinho_mesa_vinifera = ['6-Tinto', '7-Branco', '8-Rosado']
producao_vinho_mesa_vinifera = df_producao_anual.query("produto in @vinho_mesa_vinifera")
plt.figure(figsize=(10,6))
plt.title('PRODUÇÃO DE VINHO FINO DE MESA (VINÍFERA) POR ANO')
axis = sns.lineplot(data= producao_vinho_mesa_vinifera, x="ano", y="produzido", hue="produto")
axis.xaxis.set_major_locator(ticker.IndexLocator(base=5, offset=0))
plt.xticks(rotation=30)
plt.grid(linestyle='--')
plt.show()

# %% [markdown]
# Comparação entre o Vinho de mesa Tradicional e o Vinífera

# %%
vinho_tinto = ['2-Tinto', '6-Tinto']
producao_vinho_tinto = df_producao_anual.query("produto in @vinho_tinto")
plt.figure(figsize=(10,5))
plt.title('PRODUÇÃO DE VINHO TINTO TRADICIONAL E FINO DE MESA POR ANO')
axis = sns.lineplot(data= producao_vinho_tinto, x="ano", y="produzido", hue="produto")
axis.xaxis.set_major_locator(ticker.IndexLocator(base=5, offset=0))
plt.xticks(rotation=30)
plt.grid(linestyle='--')
plt.show()

vinho_branco = ['3-Branco', '7-Branco']
producao_vinho_branco = df_producao_anual.query("produto in @vinho_branco")
plt.figure(figsize=(10,5))
plt.title('PRODUÇÃO DE VINHO BRANCO TRADICIONAL E FINO DE MESA POR ANO')
axis = sns.lineplot(data= producao_vinho_branco, x="ano", y="produzido", hue="produto")
axis.xaxis.set_major_locator(ticker.IndexLocator(base=5, offset=0))
plt.xticks(rotation=30)
plt.grid(linestyle='--')
plt.show()

vinho_rosado = ['4-Rosado', '8-Rosado']
producao_vinho_rosado = df_producao_anual.query("produto in @vinho_rosado")
plt.figure(figsize=(10,5))
plt.title('PRODUÇÃO DE VINHO ROSADO TRADICIONAL E FINO DE MESA POR ANO')
axis = sns.lineplot(data= producao_vinho_rosado, x="ano", y="produzido", hue="produto")
axis.xaxis.set_major_locator(ticker.IndexLocator(base=5, offset=0))
plt.xticks(rotation=30)
plt.grid(linestyle='--')
plt.show()
